# %% [markdown]
# Dans cet exercice, vous allez devoir utiliser le dictionnaire d et la variable chemin pour créer la structure de dossiers contenue dans le dictionnaire à l'intérieur du dossier contenu dans la variable chemin.
#
# chemin = "ENTREZ UN CHEMIN DE DOSSIER DANS LEQUEL CRÉER LA STRUCTURE"
#
# d = {"Films": ["Le seigneur des anneaux",
#                "Harry Potter",
#                "Moon",
#                "Forrest Gump"],
#      "Employes": ["Paul",
#                   "Pierre",
#                   "Marie"],
#      "Exercices": ["les_variables",
#                    "les_fichiers",
#                    "les_boucles"]}
#
# Vous devez donc avoir un dossier Films qui contient les sous-dossiers Le seigneur des anneaux, Harry Potter, Moon et Forrest Gump.
#
# Pareil pour Employes et Exercices.
#
# Bonne chance !

# %%
from pathlib import Path
#chemin = r"C:\Users\Utilisateur\Desktop\VDE\python\dossier_projet_trie"
 
d = {"Films": ["Le seigneur des anneaux",
               "Harry Potter",
               "Moon",
               "Forrest Gump"],
     "Employes": ["Paul",
                  "Pierre",
                  "Marie"],
     "Exercices": ["les_variables",
                   "les_fichiers",
                   "les_boucles"]}
p = Path.home()

# On donne le chemin où se trouve le dossier
chemin = p / r"C:\Users\Utilisateur\Desktop\VDE\python"

# On va ensuite concaténer ce chemin de dossier avec un dossier qu'on va s'appeler dossier_film_employ_exo
p = p / "dossier_film_employ_exo"
# Le dossier dossier_film_employ_exo à ce niveau n'existe pas encore

# Création du dossier_film_employ_exo
p.mkdir(exist_ok = True)

# Création du dossier Film
p  = p / "films"
p.mkdir(parents = True, exist_ok = True)

# Création du sous dossier Le seigneur des anneaux
p = Path.home()
p = p / r"C:\Users\Utilisateur\dossier_film_employ_exo\films"
p = p / d["Films"][0]
p.mkdir(parents = True, exist_ok = True)

# Création du sous dossier Harry Potter
p = Path.home()
p = p / r"C:\Users\Utilisateur\dossier_film_employ_exo\films"
p = p / d["Films"][1]
p.mkdir(parents = True, exist_ok = True)

# Création du sous dossier "Moon"
p = Path.home()
p = p / r"C:\Users\Utilisateur\dossier_film_employ_exo\films"
p = p / d["Films"][2]
p.mkdir(parents = True, exist_ok = True)

# Création du sous dossier "Forrest Gump"
p = Path.home()
p = p / r"C:\Users\Utilisateur\dossier_film_employ_exo\films"
p = p / d["Films"][3]
p.mkdir(parents = True, exist_ok = True)

# Création du dossier employes
p = Path.home()
p =  p / r"C:\Users\Utilisateur\dossier_film_employ_exo"
p = p / "Employes"
p.mkdir(parents = True, exist_ok = True)

# Création du dossier Paul
p = Path.home()
p =  p / r"C:\Users\Utilisateur\dossier_film_employ_exo\Employes"
p = p / d["Employes"][0]
p.mkdir(parents = True, exist_ok = True)

# Création du dossier Pierre
p = Path.home()
p =  p / r"C:\Users\Utilisateur\dossier_film_employ_exo\Employes"
p = p / d["Employes"][1]
p.mkdir(parents = True, exist_ok = True)

# Création du dossier Marie
p = Path.home()
p =  p / r"C:\Users\Utilisateur\dossier_film_employ_exo\Employes"
p = p / d["Employes"][2]
p.mkdir(parents = True, exist_ok = True)

# création du dossier Exercices
p = Path.home()
p = p / r"C:\Users\Utilisateur\dossier_film_employ_exo"
p = p / "Exercices"
p.mkdir(parents = True, exist_ok = True)


# création du dossier les_variables
p = Path.home()
p = p / r"C:\Users\Utilisateur\dossier_film_employ_exo\Exercices"
p = p / d["Exercices"][0]
p.mkdir(parents = True, exist_ok = True)

# création du dossier les_fichiers
p = Path.home()
p = p / r"C:\Users\Utilisateur\dossier_film_employ_exo\Exercices"
p = p / d["Exercices"][1]
p.mkdir(parents = True, exist_ok = True)

# création du dossier les_boucles
p = Path.home()
p = p / r"C:\Users\Utilisateur\dossier_film_employ_exo\Exercices"
p = p / d["Exercices"][2]
p.mkdir(parents = True, exist_ok = True)

# %%
# Solution plus optimisée

from pathlib import Path

chemin = "/Users/thibh/dossier_test"

d = {"Films": ["Le seigneur des anneaux",
               "Harry Potter",
               "Moon",
               "Forrest Gump"],
     "Employes": ["Paul",
                  "Pierre",
                  "Marie"],
     "Exercices": ["les_variables",
                   "les_fichiers",
                   "les_boucles"]}


for dossier_principal, sous_dossiers in d.items():
    for dossier in sous_dossiers:
        chemin_dossier = Path(chemin) / dossier_principal / dossier
        chemin_dossier.mkdir(exist_ok=True, parents=True)
# Out:
# Le seigneur des anneaux
# Harry Potter
# Moon
# Forrest Gump
